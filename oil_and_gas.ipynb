# %% [markdown]
# Analyzing the [Kaggle Dataset](https://www.kaggle.com/djzurawski/us-oil-and-gas-production-june-2008-to-june-2018) with information about Oil and Gas production in the US from June 2008 to June 2018.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# Let's load the Gas production:

# %%
file = "data/U.S._natural_gas_production.csv"
gas_df = pd.read_csv(file, decimal=",")
gas_df.head(3)
# Out:
#         Month   U.S.  Alaska  Arkansas  Kansas  Other States  \
# 0  2008-06-01  70626    8875      1196    1024          2995
# 1  2008-07-01  71137    8375      1256    1034          3150
# 2  2008-08-01  70760    8739      1313    1033          3092
#
#    Federal Offshore--Gulf of Mexico  Wyoming  West Virginia  Utah  \
# 0                              7339     6839            670  1198
# 1                              7468     6940            674  1200
# 2                              6868     6835            678  1277
#
#    Pennsylvania  Texas  Oklahoma  Ohio  North Dakota  New Mexico  Montana  \
# 0           540  21446      5241   224           243        3975      323
# 1           512  21547      5256   220           243        4179      324
# 2           529  21777      4896   220           249        4092      327
#
#    Louisiana  Colorado  California
# 0       3989      3576         932
# 1       4008      3834         919
# 2       3896      4056         881

# %%
# Check how many rows and columns in the dataframe
gas_df.shape
# Out:
# (121, 20)

# %%
# Display all the available column names in the dataframe
gas_df.columns
# Out:
# Index(['Month', 'U.S.', 'Alaska', 'Arkansas', 'Kansas', 'Other States',
#        'Federal Offshore--Gulf of Mexico', 'Wyoming', 'West Virginia', 'Utah',
#        'Pennsylvania', 'Texas', 'Oklahoma', 'Ohio', 'North Dakota',
#        'New Mexico', 'Montana', 'Louisiana', 'Colorado', 'California'],
#       dtype='object')

# %%
# Display additional info about each columns such as data types and number of non-null values
gas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Month                             121 non-null    object
#  1   U.S.                              121 non-null    int64
#  2   Alaska                            121 non-null    int64
#  3   Arkansas                          121 non-null    int64
#  4   Kansas                            121 non-null    int64
#  5   Other States                      121 non-null    int64
#  6   Federal Offshore--Gulf of Mexico  121 non-null    int64
#  7   Wyoming                           121 non-null    int64
#  8   West Virginia                     121 non-null    int64
#  9   Utah                              121 non-null    int64
#  10  Pennsylvania                      121 non-null    int64
#  11  Texas                             121 non-null    int64
# ...

# %%
gas_df['Month'] = pd.to_datetime(gas_df['Month'])

# %%
gas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Month                             121 non-null    datetime64[ns]
#  1   U.S.                              121 non-null    int64
#  2   Alaska                            121 non-null    int64
#  3   Arkansas                          121 non-null    int64
#  4   Kansas                            121 non-null    int64
#  5   Other States                      121 non-null    int64
#  6   Federal Offshore--Gulf of Mexico  121 non-null    int64
#  7   Wyoming                           121 non-null    int64
#  8   West Virginia                     121 non-null    int64
#  9   Utah                              121 non-null    int64
#  10  Pennsylvania                      121 non-null    int64
# ...

# %% [markdown]
# ### Check your code

# %%
month_type = gas_df['Month'].dtype

# %%
from nbresult import ChallengeResult

result = ChallengeResult('date',
    month_type=month_type,
)
result.write()

# %%
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ccw888/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ccw888/code/ccw888/02-Data-Toolkit/01-Data-Analysis/data-us-oil-and-gas-production/tests
# plugins: anyio-3.6.2, asyncio-0.19.0, typeguard-2.13.3
# asyncio: mode=strict
# collecting ... collected 1 item
#
# test_date.py::TestDate::test_month_column_is_a_datetime PASSED           [100%]
#
# ============================== 1 passed in 1.21s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/date.pickle
#
# git commit -m 'Completed date step'
#
# git push origin master

# %%
gas_df['Month'].dt.year.head()
# Out:
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# Name: Month, dtype: int64

# %%
gas_df['Month'].dt.month.tail()
# Out:
# 116    2
# 117    3
# 118    4
# 119    5
# 120    6
# Name: Month, dtype: int64

# %% [markdown]
# ---
#
# ## Yearly Gas production

# %%
gas_df['year'] = gas_df['Month'].dt.year
gas_df
# Out:
#          Month   U.S.  Alaska  Arkansas  Kansas  Other States  \
# 0   2008-06-01  70626    8875      1196    1024          2995
# 1   2008-07-01  71137    8375      1256    1034          3150
# 2   2008-08-01  70760    8739      1313    1033          3092
# 3   2008-09-01  63984    9221      1316    1032          2953
# 4   2008-10-01  69464    9674      1375    1026          3113
# ..         ...    ...     ...       ...     ...           ...
# 116 2018-02-01  97225    9593      1665     565          1350
# 117 2018-03-01  98278    9542      1646     568          1391
# 118 2018-04-01  98618    9424      1712     569          1350
# 119 2018-05-01  99091    9121      1661     568          1348
# 120 2018-06-01  98428    7634      1637     538          1365
#
#      Federal Offshore--Gulf of Mexico  Wyoming  West Virginia  Utah  ...  \
# 0                                7339     6839            670  1198  ...
# ...

# %%
yearly_gas_df = gas_df.groupby('year').sum()
yearly_gas_df
# Out:
#          U.S.  Alaska  Arkansas  Kansas  Other States  \
# year
# 2008   489473   64732      9395    7229         21678
# 2009   856876  108986     22353   11689         36078
# 2010   881622  105219     30475   10708         37542
# 2011   936163  104154     35384   10191         38187
# 2012   968632  103856     37571    9714         37045
# 2013   970617  105776     37466    9613         22657
# 2014  1032439  104298     36917    9415         20761
# 2015  1082158  104447     33221    9349         20102
# 2016  1070085  105900     26999    7984         18722
# 2017  1090730  106969     23050    7247         17069
# 2018   587058   54887      9991    3372          8129
#
#       Federal Offshore--Gulf of Mexico  Wyoming  West Virginia   Utah  \
# year
# 2008                             39112    48393           4709   8726
# 2009                             80346    83413           8692  14782
# 2010                             74309    82687           8718  14361
# ...

# %% [markdown]
# ### Check your code

# %%
index_year = yearly_gas_df.index[0]
yearly_gas_shape = yearly_gas_df.shape
us_total = yearly_gas_df.iloc[0,0]

# %%
from nbresult import ChallengeResult

result = ChallengeResult('full_gas',
    index_year=index_year,
    yearly_gas_shape=yearly_gas_shape,
    us_total=us_total
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ccw888/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ccw888/code/ccw888/02-Data-Toolkit/01-Data-Analysis/data-us-oil-and-gas-production/tests
# plugins: anyio-3.6.2, asyncio-0.19.0, typeguard-2.13.3
# asyncio: mode=strict
# collecting ... collected 3 items
#
# test_full_gas.py::TestFullGas::test_df_has_the_right_index PASSED        [ 33%]
# test_full_gas.py::TestFullGas::test_df_has_the_right_shape PASSED        [ 66%]
# test_full_gas.py::TestFullGas::test_df_has_the_right_values PASSED       [100%]
#
# ============================== 3 passed in 1.99s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/full_gas.pickle
#
# git commit -m 'Completed full_gas step'
#
# git push origin master

# %%
plot = yearly_gas_df.filter(items=['U.S.']).plot(kind="bar")
plot.set_xlabel("Year");

# %%
yearly_gas_df
# Out:
#          U.S.  Alaska  Arkansas  Kansas  Other States  \
# year
# 2008   489473   64732      9395    7229         21678
# 2009   856876  108986     22353   11689         36078
# 2010   881622  105219     30475   10708         37542
# 2011   936163  104154     35384   10191         38187
# 2012   968632  103856     37571    9714         37045
# 2013   970617  105776     37466    9613         22657
# 2014  1032439  104298     36917    9415         20761
# 2015  1082158  104447     33221    9349         20102
# 2016  1070085  105900     26999    7984         18722
# 2017  1090730  106969     23050    7247         17069
# 2018   587058   54887      9991    3372          8129
#
#       Federal Offshore--Gulf of Mexico  Wyoming  West Virginia   Utah  \
# year
# 2008                             39112    48393           4709   8726
# 2009                             80346    83413           8692  14782
# 2010                             74309    82687           8718  14361
# ...

# %%
yearly_gas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 2008 to 2018
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   U.S.                              11 non-null     int64
#  1   Alaska                            11 non-null     int64
#  2   Arkansas                          11 non-null     int64
#  3   Kansas                            11 non-null     int64
#  4   Other States                      11 non-null     int64
#  5   Federal Offshore--Gulf of Mexico  11 non-null     int64
#  6   Wyoming                           11 non-null     int64
#  7   West Virginia                     11 non-null     int64
#  8   Utah                              11 non-null     int64
#  9   Pennsylvania                      11 non-null     int64
#  10  Texas                             11 non-null     int64
#  11  Oklahoma                          11 non-null     int64
# ...

# %%
yearly_gas_df.reset_index(inplace = True)
yearly_gas_df
# Out:
#     year     U.S.  Alaska  Arkansas  Kansas  Other States  \
# 0   2008   489473   64732      9395    7229         21678
# 1   2009   856876  108986     22353   11689         36078
# 2   2010   881622  105219     30475   10708         37542
# 3   2011   936163  104154     35384   10191         38187
# 4   2012   968632  103856     37571    9714         37045
# 5   2013   970617  105776     37466    9613         22657
# 6   2014  1032439  104298     36917    9415         20761
# 7   2015  1082158  104447     33221    9349         20102
# 8   2016  1070085  105900     26999    7984         18722
# 9   2017  1090730  106969     23050    7247         17069
# 10  2018   587058   54887      9991    3372          8129
#
#     Federal Offshore--Gulf of Mexico  Wyoming  West Virginia   Utah  \
# 0                              39112    48393           4709   8726
# 1                              80346    83413           8692  14782
# ...

# %%
yearly_gas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   year                              11 non-null     int64
#  1   U.S.                              11 non-null     int64
#  2   Alaska                            11 non-null     int64
#  3   Arkansas                          11 non-null     int64
#  4   Kansas                            11 non-null     int64
#  5   Other States                      11 non-null     int64
#  6   Federal Offshore--Gulf of Mexico  11 non-null     int64
#  7   Wyoming                           11 non-null     int64
#  8   West Virginia                     11 non-null     int64
#  9   Utah                              11 non-null     int64
#  10  Pennsylvania                      11 non-null     int64
#  11  Texas                             11 non-null     int64
# ...

# %%
year_gas_filter = (yearly_gas_df.year>2008) & (yearly_gas_df.year<2018)
filtered_yearly_gas_df = yearly_gas_df[year_gas_filter]
filtered_yearly_gas_df.set_index('year', inplace=True)
filtered_yearly_gas_df
# Out:
#          U.S.  Alaska  Arkansas  Kansas  Other States  \
# year
# 2009   856876  108986     22353   11689         36078
# 2010   881622  105219     30475   10708         37542
# 2011   936163  104154     35384   10191         38187
# 2012   968632  103856     37571    9714         37045
# 2013   970617  105776     37466    9613         22657
# 2014  1032439  104298     36917    9415         20761
# 2015  1082158  104447     33221    9349         20102
# 2016  1070085  105900     26999    7984         18722
# 2017  1090730  106969     23050    7247         17069
#
#       Federal Offshore--Gulf of Mexico  Wyoming  West Virginia   Utah  \
# year
# 2009                             80346    83413           8692  14782
# 2010                             74309    82687           8718  14361
# 2011                             60213    78095          12948  15170
# 2012                             50102    72988          17694  16079
# ...

# %% [markdown]
# ### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('filtered_gas',
    yearly_gas=filtered_yearly_gas_df.shape
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ccw888/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ccw888/code/ccw888/02-Data-Toolkit/01-Data-Analysis/data-us-oil-and-gas-production/tests
# plugins: anyio-3.6.2, asyncio-0.19.0, typeguard-2.13.3
# asyncio: mode=strict
# collecting ... collected 1 item
#
# test_filtered_gas.py::TestFilteredGas::test_yearly_gas_production_df_has_the_right_shape PASSED [100%]
#
# ============================== 1 passed in 0.31s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/filtered_gas.pickle
#
# git commit -m 'Completed filtered_gas step'
#
# git push origin master

# %% [markdown]
# ## State production
#
# Let's have a look at the yearly production of some specific states

# %%
filtered_yearly_gas_df.columns[1:].sort_values()
# Out:
# Index(['Alaska', 'Arkansas', 'California', 'Colorado',
#        'Federal Offshore--Gulf of Mexico', 'Kansas', 'Louisiana', 'Montana',
#        'New Mexico', 'North Dakota', 'Ohio', 'Oklahoma', 'Other States',
#        'Pennsylvania', 'Texas', 'Utah', 'West Virginia', 'Wyoming'],
#       dtype='object')

# %%
plot = filtered_yearly_gas_df.filter(items=['Colorado', 'Louisiana', 'Ohio', 'Utah']).plot()
plot.set_xlabel("Year");

# %% [markdown]
# ---
#
# ## Comparing with Crude Oil Production

# %%
file = "data/U.S._crude_oil_production.csv"
oil_df = pd.read_csv(file, decimal=",", parse_dates=['Month'])
oil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 36 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Month                                      121 non-null    datetime64[ns]
#  1   U.S. Crude Oil                             121 non-null    int64
#  2   Alabama                                    121 non-null    int64
#  3   Alaska                                     121 non-null    int64
#  4   Arkansas                                   121 non-null    int64
#  5   Arizona                                    121 non-null    int64
#  6   California                                 121 non-null    int64
#  7   Colorado                                   121 non-null    int64
#  8   Federal Offshore Gulf of Mexico Crude Oil  121 non-null    int64
#  9   Federal Offshore Pacific Crude Oil         121 non-null    int64
# ...

# %% [markdown]
# ---
#
# ## Yearly Oil production

# %%
oil_df['year'] = oil_df['Month'].dt.year
oil_df
# Out:
#          Month  U.S. Crude Oil   Alabama  Alaska  Arkansas  Arizona  \
# 0   2008-06-01             5138       21     655        17        0
# 1   2008-07-01             5177       21     640        17        0
# 2   2008-08-01             5003       21     544        17        0
# 3   2008-09-01             3974       21     681        16        0
# 4   2008-10-01             4738       21     716        17        0
# ..         ...              ...      ...     ...       ...      ...
# 116 2018-02-01            10248       17     513        14        0
# 117 2018-03-01            10461       17     512        14        0
# 118 2018-04-01            10475       17     497        14        0
# 119 2018-05-01            10443       16     496        14        0
# 120 2018-06-01            10674       16     451        14        0
#
#      California  Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# 0           583        82                                       1326
# ...

# %%
yearly_oil_df = oil_df.groupby('year').sum()
yearly_oil_df
# Out:
#       U.S. Crude Oil   Alabama  Alaska  Arkansas  Arizona  California  \
# year
# 2008            34211      149    4666       118        0        4095
# 2009            64180      236    7749       189        0        6815
# 2010            65741      234    7199       189        0        6588
# 2011            67829      275    6742       195        0        6449
# 2012            78007      312    6310       214        0        6465
# 2013            89585      342    6182       218        0        6540
# 2014           105064      323    5958       224        0        6729
# 2015           113179      318    5796       205        0        6619
# 2016           105970      266    5874       183        0        6101
# 2017           112205      224    5936       173        0        5723
# 2018            62296       99    2977        84        0        2779
#
#       Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# year
# ...

# %%
yearly_oil_df.columns
# Out:
# Index(['U.S. Crude Oil ', 'Alabama', 'Alaska', 'Arkansas', 'Arizona',
#        'California', 'Colorado', 'Federal Offshore Gulf of Mexico Crude Oil',
#        'Federal Offshore Pacific Crude Oil', 'Florida', 'Idaho', 'Illinois',
#        'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Mississippi',
#        'Missouri', 'Nebraska', 'Montana', 'Nevada', 'New Mexico', 'New York',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Pennsylvania', 'South Dakota',
#        'Wyoming', 'West Virginia', 'Virginia', 'Utah', 'Texas', 'Tennessee'],
#       dtype='object')

# %%
yearly_oil_df = yearly_oil_df.rename(columns=lambda x: x.strip())

# %%
yearly_oil_df.columns
# Out:
# Index(['U.S. Crude Oil', 'Alabama', 'Alaska', 'Arkansas', 'Arizona',
#        'California', 'Colorado', 'Federal Offshore Gulf of Mexico Crude Oil',
#        'Federal Offshore Pacific Crude Oil', 'Florida', 'Idaho', 'Illinois',
#        'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Mississippi',
#        'Missouri', 'Nebraska', 'Montana', 'Nevada', 'New Mexico', 'New York',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Pennsylvania', 'South Dakota',
#        'Wyoming', 'West Virginia', 'Virginia', 'Utah', 'Texas', 'Tennessee'],
#       dtype='object')

# %%
yearly_oil_df.filter(items=['U.S. Crude Oil']).plot(kind='bar');
plot.set_xlabel("Year");

# %%
yearly_oil_df.reset_index(inplace = True)
yearly_oil_df
# Out:
#     year  U.S. Crude Oil  Alabama  Alaska  Arkansas  Arizona  California  \
# 0   2008           34211      149    4666       118        0        4095
# 1   2009           64180      236    7749       189        0        6815
# 2   2010           65741      234    7199       189        0        6588
# 3   2011           67829      275    6742       195        0        6449
# 4   2012           78007      312    6310       214        0        6465
# 5   2013           89585      342    6182       218        0        6540
# 6   2014          105064      323    5958       224        0        6729
# 7   2015          113179      318    5796       205        0        6619
# 8   2016          105970      266    5874       183        0        6101
# 9   2017          112205      224    5936       173        0        5723
# 10  2018           62296       99    2977        84        0        2779
#
#     Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# ...

# %%
year_oil_filter = (yearly_oil_df.year>2008) & (yearly_oil_df.year<2018)
filtered_yearly_oil_df = yearly_oil_df[year_oil_filter]
filtered_yearly_oil_df.set_index('year', inplace=True)
filtered_yearly_oil_df
# Out:
#       U.S. Crude Oil  Alabama  Alaska  Arkansas  Arizona  California  \
# year
# 2009           64180      236    7749       189        0        6815
# 2010           65741      234    7199       189        0        6588
# 2011           67829      275    6742       195        0        6449
# 2012           78007      312    6310       214        0        6465
# 2013           89585      342    6182       218        0        6540
# 2014          105064      323    5958       224        0        6729
# 2015          113179      318    5796       205        0        6619
# 2016          105970      266    5874       183        0        6101
# 2017          112205      224    5936       173        0        5723
#
#       Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# year
# 2009       998                                      18727
# 2010      1086                                      18640
# 2011      1295                                      15805
# ...

# %% [markdown]
# ### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('oil',
    filtered_oil_shape=filtered_yearly_oil_df.shape,
    filtered_oil_index_year=filtered_yearly_oil_df.index[0],
    us_total=filtered_yearly_oil_df.iloc[0,0]
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ccw888/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ccw888/code/ccw888/02-Data-Toolkit/01-Data-Analysis/data-us-oil-and-gas-production/tests
# plugins: anyio-3.6.2, asyncio-0.19.0, typeguard-2.13.3
# asyncio: mode=strict
# collecting ... collected 3 items
#
# test_oil.py::TestOil::test_df_has_the_right_index PASSED                 [ 33%]
# test_oil.py::TestOil::test_df_has_the_right_shape PASSED                 [ 66%]
# test_oil.py::TestOil::test_df_has_the_right_values PASSED                [100%]
#
# ============================== 3 passed in 2.65s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/oil.pickle
#
# git commit -m 'Completed oil step'
#
# git push origin master

# %% [markdown]
# ## Merging Oil and Gas Production

# %%
filtered_yearly_oil_df
# Out:
#       U.S. Crude Oil  Alabama  Alaska  Arkansas  Arizona  California  \
# year
# 2009           64180      236    7749       189        0        6815
# 2010           65741      234    7199       189        0        6588
# 2011           67829      275    6742       195        0        6449
# 2012           78007      312    6310       214        0        6465
# 2013           89585      342    6182       218        0        6540
# 2014          105064      323    5958       224        0        6729
# 2015          113179      318    5796       205        0        6619
# 2016          105970      266    5874       183        0        6101
# 2017          112205      224    5936       173        0        5723
#
#       Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# year
# 2009       998                                      18727
# 2010      1086                                      18640
# 2011      1295                                      15805
# ...

# %%
filtered_yearly_oil_df.columns
# Out:
# Index(['U.S. Crude Oil', 'Alabama', 'Alaska', 'Arkansas', 'Arizona',
#        'California', 'Colorado', 'Federal Offshore Gulf of Mexico Crude Oil',
#        'Federal Offshore Pacific Crude Oil', 'Florida', 'Idaho', 'Illinois',
#        'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Mississippi',
#        'Missouri', 'Nebraska', 'Montana', 'Nevada', 'New Mexico', 'New York',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Pennsylvania', 'South Dakota',
#        'Wyoming', 'West Virginia', 'Virginia', 'Utah', 'Texas', 'Tennessee'],
#       dtype='object')

# %%
total_oil_yearly = filtered_yearly_oil_df.iloc[:,[0]]
total_oil_yearly
# Out:
#       U.S. Crude Oil
# year
# 2009           64180
# 2010           65741
# 2011           67829
# 2012           78007
# 2013           89585
# 2014          105064
# 2015          113179
# 2016          105970
# 2017          112205

# %%
filtered_yearly_gas_df
# Out:
#          U.S.  Alaska  Arkansas  Kansas  Other States  \
# year
# 2009   856876  108986     22353   11689         36078
# 2010   881622  105219     30475   10708         37542
# 2011   936163  104154     35384   10191         38187
# 2012   968632  103856     37571    9714         37045
# 2013   970617  105776     37466    9613         22657
# 2014  1032439  104298     36917    9415         20761
# 2015  1082158  104447     33221    9349         20102
# 2016  1070085  105900     26999    7984         18722
# 2017  1090730  106969     23050    7247         17069
#
#       Federal Offshore--Gulf of Mexico  Wyoming  West Virginia   Utah  \
# year
# 2009                             80346    83413           8692  14782
# 2010                             74309    82687           8718  14361
# 2011                             60213    78095          12948  15170
# 2012                             50102    72988          17694  16079
# ...

# %%
filtered_yearly_gas_df.columns
# Out:
# Index(['U.S.', 'Alaska', 'Arkansas', 'Kansas', 'Other States',
#        'Federal Offshore--Gulf of Mexico', 'Wyoming', 'West Virginia', 'Utah',
#        'Pennsylvania', 'Texas', 'Oklahoma', 'Ohio', 'North Dakota',
#        'New Mexico', 'Montana', 'Louisiana', 'Colorado', 'California'],
#       dtype='object')

# %%
total_gas_yearly = filtered_yearly_gas_df.iloc[:,[0]]
total_gas_yearly
# Out:
#          U.S.
# year
# 2009   856876
# 2010   881622
# 2011   936163
# 2012   968632
# 2013   970617
# 2014  1032439
# 2015  1082158
# 2016  1070085
# 2017  1090730

# %%
merged_df = pd.concat([total_oil_yearly, total_gas_yearly], axis=1)
merged_df
# Out:
#       U.S. Crude Oil     U.S.
# year
# 2009           64180   856876
# 2010           65741   881622
# 2011           67829   936163
# 2012           78007   968632
# 2013           89585   970617
# 2014          105064  1032439
# 2015          113179  1082158
# 2016          105970  1070085
# 2017          112205  1090730

# %%
merged_df.rename(columns = {'U.S. Crude Oil':'Crude Oil', 'U.S.':'Gas'}, inplace = True)
merged_df
# Out:
#       Crude Oil      Gas
# year
# 2009      64180   856876
# 2010      65741   881622
# 2011      67829   936163
# 2012      78007   968632
# 2013      89585   970617
# 2014     105064  1032439
# 2015     113179  1082158
# 2016     105970  1070085
# 2017     112205  1090730

# %%
plot = merged_df.plot(kind="bar")
plot.set_xlabel("Year")
plot.legend(['Gas (Millions of Cubic feet)', 'Crude Oil (Thousands of barrels)']);

# %% [markdown]
# ### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('merged_dataframes',
    merged_df_shape=merged_df.shape,
    yearly_oil_2009=merged_df.iloc[0]["Crude Oil"],
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ccw888/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ccw888/code/ccw888/02-Data-Toolkit/01-Data-Analysis/data-us-oil-and-gas-production/tests
# plugins: anyio-3.6.2, asyncio-0.19.0, typeguard-2.13.3
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_merged_dataframes.py::TestMergedDataframes::test_merged_df_has_the_right_shape PASSED [ 50%]
# test_merged_dataframes.py::TestMergedDataframes::test_yearly_oil_value_2009 PASSED [100%]
#
# ============================== 2 passed in 1.10s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/merged_dataframes.pickle
#
# git commit -m 'Completed merged_dataframes step'
#
# git push origin master

# %%
gas_df.set_index('Month', inplace=True)

# %% [markdown]
# # Step 1 - Ensure Stationarity

# %%
from statsmodels.tsa.stattools import adfuller

print('ADF for gas: ', adfuller(gas_df['U.S.'])[1])  # p-value
# Out:
# ADF for gas:  0.8930505750541602

# %%
y_gas = gas_df['U.S.']
y_gas
# Out:
# Month
# 2008-06-01    70626
# 2008-07-01    71137
# 2008-08-01    70760
# 2008-09-01    63984
# 2008-10-01    69464
#               ...
# 2018-02-01    97225
# 2018-03-01    98278
# 2018-04-01    98618
# 2018-05-01    99091
# 2018-06-01    98428
# Name: U.S., Length: 121, dtype: int64

# %%
plt.subplot(1,2,1)
# non_differenced_data = pd.Series(y)
gas_differenced_1 = y_gas.diff().dropna()
gas_differenced_1.plot();
plt.title('gas first difference')

plt.subplot(1,2,2)
gas_differenced_2 = gas_differenced_1.diff().dropna()
gas_differenced_2.plot()
plt.title('gas second difference')
# Out:
# Text(0.5, 1.0, 'gas second difference')

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(1, 2,figsize=(15,4))


plot_acf(gas_differenced_1, lags=50, ax=axes[0]);
axes[0].set_title('AutoCorr Plot: 1st Order Differencing');


plot_acf(gas_differenced_2, lags=50, ax=axes[1]);
axes[1].set_title('AutoCorr Plot: 2nd Order Differencing');

# %% [markdown]
# ## d=1

# %% [markdown]
# # Step 2 - Select AR order (p) and MA order (q)

# %%
# ACF / PACF analysis of y_diff linearized
plot_acf(gas_differenced_1, lags=50);
plt.title('AutoCorr Plot: 1st Order Differencing');

# %% [markdown]
# # q=1

# %%
plot_pacf(gas_differenced_1, lags=48, c='r');
plt.title('Partial AutoCorr Plot: 1st Order Differencing');
# Out:
# /home/ccw888/.pyenv/versions/lewagon/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# # p=1

# %% [markdown]
# # Step 3 - Build Model

# %%
p=1;
d=1;
q=1;



from statsmodels.tsa.arima.model import ARIMA  #statsmodels 0.12+

arima = ARIMA(y_gas, order=(p,d,q))
arima = arima.fit()

arima.summary()
# Out:
# /home/ccw888/.pyenv/versions/lewagon/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /home/ccw888/.pyenv/versions/lewagon/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /home/ccw888/.pyenv/versions/lewagon/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /home/ccw888/.pyenv/versions/lewagon/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# ...

# %%
import pmdarima as pm
smodel = pm.auto_arima(y_gas,
                       start_p=1, max_p=2,
                       d=1, max_d = 2,
                       start_q=1, max_q=2,

                       seasonal=False,
                       trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2086.257, Time=2.29 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2088.754, Time=0.20 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2090.762, Time=0.38 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2090.752, Time=1.73 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2089.855, Time=0.17 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2091.742, Time=2.87 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2101.355, Time=2.74 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2092.275, Time=3.79 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2092.295, Time=0.73 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2090.308, Time=5.97 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=inf, Time=2.82 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0] intercept
# Total fit time: 23.812 seconds

# %% [markdown]
# # 3. Evaluate model performance

# %%
from statsmodels.graphics.tsaplots import plot_predict

fig, axs = plt.subplots(1, 1, figsize=(12, 5))
axs.plot(y_gas, label='true value')
plot_predict(arima, start=1, ax=axs);

# %%
fig, axs = plt.subplots(1, 1, figsize=(12, 5))
axs.plot(y_gas, label='true value')
plot_predict(arima, start=1, ax=axs, dynamic=True);

# %% [markdown]
# # 4 Out-of-Sample Forecasts (real "future")

# %%
y_gas.shape
# Out:
# (121,)

# %%
# Create a correct train_test_split to predict the last 50 points
y_train = y_gas[0:85]
y_test = y_gas[85:]

# Build model
arima = ARIMA(y_train, order=(1,1,1))
arima = arima.fit()
# Out:
# /home/ccw888/.pyenv/versions/lewagon/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /home/ccw888/.pyenv/versions/lewagon/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /home/ccw888/.pyenv/versions/lewagon/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
## Forecast
# Forecast values
forecast = arima.forecast(len(y_test), alpha=0.05)  # 95% confidence

# Forecast values and confidence intervals
forecast_results = arima.get_forecast(len(y_test), alpha=0.05)
forecast = forecast_results.predicted_mean
confidence_int = forecast_results.conf_int().values

# %%
# We define here a "Plot forecast vs. real", which also shows historical training set

def plot_forecast(fc, train, test, upper=None, lower=None):
    is_confidence_int = isinstance(upper, np.ndarray) and isinstance(lower, np.ndarray)
    # Prepare plot series
    fc_series = pd.Series(fc, index=test.index)
    lower_series = pd.Series(upper, index=test.index) if is_confidence_int else None
    upper_series = pd.Series(lower, index=test.index) if is_confidence_int else None

    # Plot
    plt.figure(figsize=(10,4), dpi=100)
    plt.plot(y_train, label='training', color='black')
    plt.plot(y_test, label='actual', color='black', ls='--')
    plt.plot(fc_series, label='forecast', color='orange')
    if is_confidence_int:
        plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.15)
    plt.title('Forecast vs Actuals')
    plt.legend(loc='upper left', fontsize=8);

# %%
plot_forecast(forecast, y_train, y_test, confidence_int[:,0], confidence_int[:,1])
